# %%
import pandas as pd
bond=pd.read_csv("jamesbond.csv")

bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond=pd.read_csv("jamesbond.csv",index_col="Year")

bond.head()
# Out:
#                        Film         Actor       Director  Box Office  Budget  \
# Year
# 1962                 Dr. No  Sean Connery  Terence Young       448.8     7.0
# 1963  From Russia with Love  Sean Connery  Terence Young       543.8    12.6
# 1964             Goldfinger  Sean Connery   Guy Hamilton       820.4    18.6
# 1965            Thunderball  Sean Connery  Terence Young       848.1    41.9
# 1967          Casino Royale   David Niven     Ken Hughes       315.0    85.0
#
#       Bond Actor Salary
# Year
# 1962                0.6
# 1963                1.6
# 1964                3.2
# 1965                4.7
# 1967                NaN

# %%
# for indexing we can use set_index 
import pandas as pd
bond1=pd.read_csv("jamesbond.csv")

bond1.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond1.set_index("Film",inplace=True)
bond1.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond1.reset_index().head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond1.reset_index(drop=True).head()
# Out:
#    Year         Actor       Director  Box Office  Budget  Bond Actor Salary
# 0  1962  Sean Connery  Terence Young       448.8     7.0                0.6
# 1  1963  Sean Connery  Terence Young       543.8    12.6                1.6
# 2  1964  Sean Connery   Guy Hamilton       820.4    18.6                3.2
# 3  1965  Sean Connery  Terence Young       848.1    41.9                4.7
# 4  1967   David Niven     Ken Hughes       315.0    85.0                NaN

# %%
import pandas as pd
bond=pd.read_csv("jamesbond.csv",index_col="Year")
bond.sort_index(inplace=True)
bond.head()
# Out:
#                        Film         Actor       Director  Box Office  Budget  \
# Year
# 1962                 Dr. No  Sean Connery  Terence Young       448.8     7.0
# 1963  From Russia with Love  Sean Connery  Terence Young       543.8    12.6
# 1964             Goldfinger  Sean Connery   Guy Hamilton       820.4    18.6
# 1965            Thunderball  Sean Connery  Terence Young       848.1    41.9
# 1967          Casino Royale   David Niven     Ken Hughes       315.0    85.0
#
#       Bond Actor Salary
# Year
# 1962                0.6
# 1963                1.6
# 1964                3.2
# 1965                4.7
# 1967                NaN

# %%
bond.loc["1964"]
# Out:
# Film                   Goldfinger
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  820.4
# Budget                       18.6
# Bond Actor Salary             3.2
# Name: 1964, dtype: object

# %%
bond.loc["1964":'1968']
# Out:
#                      Film         Actor       Director  Box Office  Budget  \
# Year
# 1964           Goldfinger  Sean Connery   Guy Hamilton       820.4    18.6
# 1965          Thunderball  Sean Connery  Terence Young       848.1    41.9
# 1967        Casino Royale   David Niven     Ken Hughes       315.0    85.0
# 1967  You Only Live Twice  Sean Connery  Lewis Gilbert       514.2    59.9
#
#       Bond Actor Salary
# Year
# 1964                3.2
# 1965                4.7
# 1967                NaN
# 1967                4.4

# %%
bond.loc[["1979"]]
# Out:
#            Film        Actor       Director  Box Office  Budget  \
# Year
# 1979  Moonraker  Roger Moore  Lewis Gilbert       535.0    91.5
#
#       Bond Actor Salary
# Year
# 1979                NaN

# %%
import pandas as pd
bond1=pd.read_csv("jamesbond.csv")

bond1.loc[15]
# Out:
# Film                 A View to a Kill
# Year                             1985
# Actor                     Roger Moore
# Director                    John Glen
# Box Office                      275.2
# Budget                           54.5
# Bond Actor Salary                 9.1
# Name: 15, dtype: object

# %%
bond1.iloc[15]
# Out:
# Film                 A View to a Kill
# Year                             1985
# Actor                     Roger Moore
# Director                    John Glen
# Box Office                      275.2
# Budget                           54.5
# Bond Actor Salary                 9.1
# Name: 15, dtype: object

# %%
bond1.iloc[[11,22]]
# Out:
#              Film  Year         Actor         Director  Box Office  Budget  \
# 11      Moonraker  1979   Roger Moore    Lewis Gilbert       535.0    91.5
# 22  Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
#
#     Bond Actor Salary
# 11                NaN
# 22                3.3

# %%
bond1.iloc[11:16]
# Out:
#                      Film  Year         Actor        Director  Box Office  \
# 11              Moonraker  1979   Roger Moore   Lewis Gilbert       535.0
# 12     For Your Eyes Only  1981   Roger Moore       John Glen       449.4
# 13  Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0
# 14              Octopussy  1983   Roger Moore       John Glen       373.8
# 15       A View to a Kill  1985   Roger Moore       John Glen       275.2
#
#     Budget  Bond Actor Salary
# 11    91.5                NaN
# 12    60.2                NaN
# 13    86.0                NaN
# 14    53.9                7.8
# 15    54.5                9.1

# %%
bond1.iloc[:3]
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
bond1.iloc[11:16:2]
# Out:
#                      Film  Year         Actor        Director  Box Office  \
# 11              Moonraker  1979   Roger Moore   Lewis Gilbert       535.0
# 13  Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0
# 15       A View to a Kill  1985   Roger Moore       John Glen       275.2
#
#     Budget  Bond Actor Salary
# 11    91.5                NaN
# 13    86.0                NaN
# 15    54.5                9.1

# %%
import pandas as pd
bond=pd.read_csv("jamesbond.csv",index_col="Film")
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.loc["Die Another Day"]
# Out:
# Year                           2002
# Actor                Pierce Brosnan
# Director               Lee Tamahori
# Box Office                    465.4
# Budget                        154.2
# Bond Actor Salary              17.9
# Name: Die Another Day, dtype: object

# %%
bond.iloc[3]
# Out:
# Year                         1971
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  442.5
# Budget                       34.7
# Bond Actor Salary             5.8
# Name: Diamonds Are Forever, dtype: object

# %%
bond.ix["Die Another Day"]
# Out:
# c:\users\anuragmishra\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Year                           2002
# Actor                Pierce Brosnan
# Director               Lee Tamahori
# Box Office                    465.4
# Budget                        154.2
# Bond Actor Salary              17.9
# Name: Die Another Day, dtype: object

# %%
bond.loc["Die Another Day","Actor"]
# Out:
# 'Pierce Brosnan'

# %%
bond.loc["Die Another Day","Actor":"Budget"]
# Out:
# Actor         Pierce Brosnan
# Director        Lee Tamahori
# Box Office             465.4
# Budget                 154.2
# Name: Die Another Day, dtype: object

# %%
bond.loc["Die Another Day",["Actor","Budget"]]
# Out:
# Actor     Pierce Brosnan
# Budget             154.2
# Name: Die Another Day, dtype: object

# %%
bond.iloc[14,2]
# Out:
# 'John Glen'

# %%
bond.iloc[14,2:5]
# Out:
# Director      John Glen
# Box Office        373.8
# Budget             53.9
# Name: Octopussy, dtype: object

# %%
bond.iloc[14,[2,5]]
# Out:
# Director             John Glen
# Bond Actor Salary          7.8
# Name: Octopussy, dtype: object

# %%
#change value using ix

bond.ix["Die Another Day"]
# Out:
# c:\users\anuragmishra\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Year                           2002
# Actor                Pierce Brosnan
# Director               Lee Tamahori
# Box Office                    465.4
# Budget                        154.2
# Bond Actor Salary              17.9
# Name: Die Another Day, dtype: object

# %%
bond.ix["Die Another Day","Actor"]="sir Pierce Brosnan"
# Out:
# c:\users\anuragmishra\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
bond.ix["Die Another Day"]
# Out:
# c:\users\anuragmishra\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Year                               2002
# Actor                sir Pierce Brosnan
# Director                   Lee Tamahori
# Box Office                        465.4
# Budget                            154.2
# Bond Actor Salary                  17.9
# Name: Die Another Day, dtype: object

# %%
bond.ix["Die Another Day",["Actor","Budget"]]=["sir Pierce Brosnan", 154.22]
# Out:
# c:\users\anuragmishra\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
bond.ix["Die Another Day"]
# Out:
# c:\users\anuragmishra\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Year                               2002
# Actor                sir Pierce Brosnan
# Director                   Lee Tamahori
# Box Office                        465.4
# Budget                           154.22
# Bond Actor Salary                  17.9
# Name: Die Another Day, dtype: object

# %%
# set multiple values

# %%
mask=bond["Actor"]=="Sean Connery"
bond[mask]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# ...

# %%
df2=bond[mask]

# %%
df2["Actor"]="sir Sean Connery"
# Out:
# c:\users\anuragmishra\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2
# Out:
#                        Year             Actor        Director  Box Office  \
# Film
# Diamonds Are Forever   1971  sir Sean Connery    Guy Hamilton       442.5
# Dr. No                 1962  sir Sean Connery   Terence Young       448.8
# From Russia with Love  1963  sir Sean Connery   Terence Young       543.8
# Goldfinger             1964  sir Sean Connery    Guy Hamilton       820.4
# Never Say Never Again  1983  sir Sean Connery  Irvin Kershner       380.0
# Thunderball            1965  sir Sean Connery   Terence Young       848.1
# You Only Live Twice    1967  sir Sean Connery   Lewis Gilbert       514.2
#
#                        Budget  Bond Actor Salary
# Film
# Diamonds Are Forever     34.7                5.8
# Dr. No                    7.0                0.6
# From Russia with Love    12.6                1.6
# Goldfinger               18.6                3.2
# Never Say Never Again    86.0                NaN
# Thunderball              41.9                4.7
# ...

# %%
# rename index labelcoloum

# %%
bond.rename(columns={"Year":"Release year","Budget":"Budgets"},inplace=True)

# %%
bond.head()
# Out:
#                       Release year               Actor         Director  \
# Film
# A View to a Kill              1985         Roger Moore        John Glen
# Casino Royale                 2006        Daniel Craig  Martin Campbell
# Casino Royale                 1967         David Niven       Ken Hughes
# Diamonds Are Forever          1971        Sean Connery     Guy Hamilton
# Die Another Day               2002  sir Pierce Brosnan     Lee Tamahori
#
#                       Box Office  Budgets  Bond Actor Salary
# Film
# A View to a Kill           275.2    54.50                9.1
# Casino Royale              581.5   145.30                3.3
# Casino Royale              315.0    85.00                NaN
# Diamonds Are Forever       442.5    34.70                5.8
# Die Another Day            465.4   154.22               17.9

# %%
#delete row or coulm

bond.drop("Box Office",axis=1)  #use inplace for permanent change
# Out:
#                       Release year               Actor         Director  \
# Film
# A View to a Kill              1985         Roger Moore        John Glen
# Casino Royale                 2006        Daniel Craig  Martin Campbell
# Casino Royale                 1967         David Niven       Ken Hughes
# Diamonds Are Forever          1971        Sean Connery     Guy Hamilton
# Die Another Day               2002  sir Pierce Brosnan     Lee Tamahori
#
#                       Box Office  Budgets  Bond Actor Salary
# Film
# A View to a Kill           275.2    54.50                9.1
# Casino Royale              581.5   145.30                3.3
# Casino Royale              315.0    85.00                NaN
# Diamonds Are Forever       442.5    34.70                5.8
# Die Another Day            465.4   154.22               17.9

# %%
bond.drop("A View to a Kill")
# Out:
#                                  Release year               Actor  \
# Film
# Casino Royale                            2006        Daniel Craig
# Casino Royale                            1967         David Niven
# Diamonds Are Forever                     1971        Sean Connery
# Die Another Day                          2002  sir Pierce Brosnan
# Dr. No                                   1962        Sean Connery
# For Your Eyes Only                       1981         Roger Moore
# From Russia with Love                    1963        Sean Connery
# GoldenEye                                1995      Pierce Brosnan
# Goldfinger                               1964        Sean Connery
# Licence to Kill                          1989      Timothy Dalton
# Live and Let Die                         1973         Roger Moore
# Moonraker                                1979         Roger Moore
# Never Say Never Again                    1983        Sean Connery
# ...

# %%
#create random sample

# %%
import pandas as pd
bond2=pd.read_csv("jamesbond.csv",index_col="Film")
bond.sort_index(inplace=True)

bond2.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond2.sample(3)
# Out:
#                    Year         Actor         Director  Box Office  Budget  \
# Film
# Quantum of Solace  2008  Daniel Craig     Marc Forster       514.2   181.4
# Casino Royale      2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale      1967   David Niven       Ken Hughes       315.0    85.0
#
#                    Bond Actor Salary
# Film
# Quantum of Solace                8.1
# Casino Royale                    3.3
# Casino Royale                    NaN

# %%
bond2.sample(frac=.25)
# Out:
#                              Year         Actor        Director  Box Office  \
# Film
# The Spy Who Loved Me         1977   Roger Moore   Lewis Gilbert       533.0
# Moonraker                    1979   Roger Moore   Lewis Gilbert       535.0
# Never Say Never Again        1983  Sean Connery  Irvin Kershner       380.0
# The Man with the Golden Gun  1974   Roger Moore    Guy Hamilton       334.0
# Goldfinger                   1964  Sean Connery    Guy Hamilton       820.4
# Quantum of Solace            2008  Daniel Craig    Marc Forster       514.2
#
#                              Budget  Bond Actor Salary
# Film
# The Spy Who Loved Me           45.1                NaN
# Moonraker                      91.5                NaN
# Never Say Never Again          86.0                NaN
# The Man with the Golden Gun    27.7                NaN
# Goldfinger                     18.6                3.2
# Quantum of Solace             181.4                8.1

# %%
bond2.sample(n=3,axis=0)
# Out:
#                                  Year           Actor       Director  \
# Film
# Live and Let Die                 1973     Roger Moore   Guy Hamilton
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# Die Another Day                  2002  Pierce Brosnan   Lee Tamahori
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Live and Let Die                      460.3    30.8                NaN
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Die Another Day                       465.4   154.2               17.9

# %%
bond2.sample(n=3,axis="rows")
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# Thunderball            1965    Sean Connery    Terence Young       848.1
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
#
#                        Budget  Bond Actor Salary
# Film
# Thunderball              41.9                4.7
# From Russia with Love    12.6                1.6
# GoldenEye                76.9                5.1

# %%
bond2.sample(n=3,axis="index")
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# Skyfall               2012    Daniel Craig       Sam Mendes       943.5
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# The Living Daylights  1987  Timothy Dalton        John Glen       313.5
#
#                       Budget  Bond Actor Salary
# Film
# Skyfall                170.2               14.5
# Casino Royale          145.3                3.3
# The Living Daylights    68.8                5.2

# %%
bond2.sample(n=3,axis=1)  #axis=0 row     axis=1 coloum
# Out:
#                                            Director  Bond Actor Salary  \
# Film
# Dr. No                                Terence Young                0.6
# From Russia with Love                 Terence Young                1.6
# Goldfinger                             Guy Hamilton                3.2
# Thunderball                           Terence Young                4.7
# Casino Royale                            Ken Hughes                NaN
# You Only Live Twice                   Lewis Gilbert                4.4
# On Her Majesty's Secret Service       Peter R. Hunt                0.6
# Diamonds Are Forever                   Guy Hamilton                5.8
# Live and Let Die                       Guy Hamilton                NaN
# The Man with the Golden Gun            Guy Hamilton                NaN
# The Spy Who Loved Me                  Lewis Gilbert                NaN
# Moonraker                             Lewis Gilbert                NaN
# ...

# %%
# smallest largets
import pandas as pd
bond2=pd.read_csv("jamesbond.csv",index_col="Film")
bond.sort_index(inplace=True)

bond2.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond2.nlargest(3,"Box Office")
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond2.nsmallest(2,"Box Office")
# Out:
#                   Year           Actor   Director  Box Office  Budget  \
# Film
# Licence to Kill   1989  Timothy Dalton  John Glen       250.9    56.7
# A View to a Kill  1985     Roger Moore  John Glen       275.2    54.5
#
#                   Bond Actor Salary
# Film
# Licence to Kill                 7.9
# A View to a Kill                9.1

# %%
bond2.nlargest(3,columns="Budget")
# Out:
#                    Year         Actor      Director  Box Office  Budget  \
# Film
# Spectre            2015  Daniel Craig    Sam Mendes       726.7   206.3
# Quantum of Solace  2008  Daniel Craig  Marc Forster       514.2   181.4
# Skyfall            2012  Daniel Craig    Sam Mendes       943.5   170.2
#
#                    Bond Actor Salary
# Film
# Spectre                          NaN
# Quantum of Solace                8.1
# Skyfall                         14.5

# %%
bond2["Budget"].nlargest(2)
# Out:
# Film
# Spectre              206.3
# Quantum of Solace    181.4
# Name: Budget, dtype: float64

# %%
#.where method

# %%
maskk=bond2["Actor"]=="Sean Connery"

# %%
bond2[maskk]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# You Only Live Twice                  4.4
# Diamonds Are Forever                 5.8
# ...

# %%
bond2.where(maskk)
# Out:
#                                    Year         Actor        Director  \
# Film
# Dr. No                           1962.0  Sean Connery   Terence Young
# From Russia with Love            1963.0  Sean Connery   Terence Young
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Thunderball                      1965.0  Sean Connery   Terence Young
# Casino Royale                       NaN           NaN             NaN
# You Only Live Twice              1967.0  Sean Connery   Lewis Gilbert
# On Her Majesty's Secret Service     NaN           NaN             NaN
# Diamonds Are Forever             1971.0  Sean Connery    Guy Hamilton
# Live and Let Die                    NaN           NaN             NaN
# The Man with the Golden Gun         NaN           NaN             NaN
# The Spy Who Loved Me                NaN           NaN             NaN
# Moonraker                           NaN           NaN             NaN
# ...

# %%
bond2.where(bond2["Box Office"]>800)
# Out:
#                                    Year         Actor       Director  \
# Film
# Dr. No                              NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# Goldfinger                       1964.0  Sean Connery   Guy Hamilton
# Thunderball                      1965.0  Sean Connery  Terence Young
# Casino Royale                       NaN           NaN            NaN
# You Only Live Twice                 NaN           NaN            NaN
# On Her Majesty's Secret Service     NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# The Man with the Golden Gun         NaN           NaN            NaN
# The Spy Who Loved Me                NaN           NaN            NaN
# Moonraker                           NaN           NaN            NaN
# ...

# %%
maskkk=(bond2["Box Office"]>800)

# %%
bond2.where(maskk & maskkk)
# Out:
#                                    Year         Actor       Director  \
# Film
# Dr. No                              NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# Goldfinger                       1964.0  Sean Connery   Guy Hamilton
# Thunderball                      1965.0  Sean Connery  Terence Young
# Casino Royale                       NaN           NaN            NaN
# You Only Live Twice                 NaN           NaN            NaN
# On Her Majesty's Secret Service     NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# The Man with the Golden Gun         NaN           NaN            NaN
# The Spy Who Loved Me                NaN           NaN            NaN
# Moonraker                           NaN           NaN            NaN
# ...

# %%
# .querry method  .apply()  vedio 74 75 72
